# %%
# FaceOff with refiner IP-Adapter
import numpy as np

time_costs = [
103.1680281162262,
102.21246457099915,
102.11145353317261,
101.37634491920471,
101.04195713996887,
]
time_costs = np.array(time_costs)
mean = np.mean(time_costs)
std = np.std(time_costs, ddof=1)
print("mean:", mean)
print("std:", std)
# Out:
# mean: 101.98204965591431
# std: 0.8256866039054788
